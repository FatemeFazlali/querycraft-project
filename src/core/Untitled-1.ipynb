# %%
from django.db import connection
with connection.cursor() as cursor:
    cursor.execute("SELECT COUNT(*) FROM core_customer")
    result = cursor.fetchone()
    print(result)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\asgiref\local.py:19, in _CVar.__getattr__(self, key)
#      18 try:
# ---> 19     return storage_object[key]
#      20 except KeyError:
#
# KeyError: 'default'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\connection.py:58, in BaseConnectionHandler.__getitem__(self, alias)
#      57 try:
# ---> 58     return getattr(self._connections, alias)
#      59 except AttributeError:
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\asgiref\local.py:121, in Local.__getattr__(self, key)
#     120 with self._lock_storage() as storage:
# --> 121     return getattr(storage, key)
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\asgiref\local.py:21, in _CVar.__getattr__(self, key)
#      20 except KeyError:
# ---> 21     raise AttributeError(f"{self!r} object has no attribute {key!r}")
#
# AttributeError: <asgiref.local._CVar object at 0x0000017D9B6EA990> object has no attribute 'default'
#
# During handling of the above exception, another exception occurred:
#
# ImproperlyConfigured                      Traceback (most recent call last)
# Cell In[1], line 2
#       1 from django.db import connection
# ----> 2 with connection.cursor() as cursor:
#       3     cursor.execute("SELECT COUNT(*) FROM core_customer")
#       4     result = cursor.fetchone()
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\connection.py:15, in ConnectionProxy.__getattr__(self, item)
#      14 def __getattr__(self, item):
# ---> 15     return getattr(self._connections[self._alias], item)
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\connection.py:60, in BaseConnectionHandler.__getitem__(self, alias)
#      58     return getattr(self._connections, alias)
#      59 except AttributeError:
# ---> 60     if alias not in self.settings:
#      61         raise self.exception_class(f"The connection '{alias}' doesn't exist.")
#      62 conn = self.create_connection(alias)
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\functional.py:47, in cached_property.__get__(self, instance, cls)
#      45 if instance is None:
#      46     return self
# ---> 47 res = instance.__dict__[self.name] = self.func(instance)
#      48 return res
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\connection.py:45, in BaseConnectionHandler.settings(self)
#      43 @cached_property
#      44 def settings(self):
# ---> 45     self._settings = self.configure_settings(self._settings)
#      46     return self._settings
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\db\utils.py:148, in ConnectionHandler.configure_settings(self, databases)
#     147 def configure_settings(self, databases):
# --> 148     databases = super().configure_settings(databases)
#     149     if databases == {}:
#     150         databases[DEFAULT_DB_ALIAS] = {"ENGINE": "django.db.backends.dummy"}
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\utils\connection.py:50, in BaseConnectionHandler.configure_settings(self, settings)
#      48 def configure_settings(self, settings):
#      49     if settings is None:
# ---> 50         settings = getattr(django_settings, self.settings_name)
#      51     return settings
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\conf\__init__.py:81, in LazySettings.__getattr__(self, name)
#      79 """Return the value of a setting and cache it in self.__dict__."""
#      80 if (_wrapped := self._wrapped) is empty:
# ---> 81     self._setup(name)
#      82     _wrapped = self._wrapped
#      83 val = getattr(_wrapped, name)
#
# File c:\Users\Fazlali_f\AppData\Local\Programs\Python\Python313\Lib\site-packages\django\conf\__init__.py:61, in LazySettings._setup(self, name)
#      59 if not settings_module:
#      60     desc = ("setting %s" % name) if name else "settings"
# ---> 61     raise ImproperlyConfigured(
#      62         "Requested %s, but settings are not configured. "
#      63         "You must either define the environment variable %s "
#      64         "or call settings.configure() before accessing settings."
#      65         % (desc, ENVIRONMENT_VARIABLE)
#      66     )
#      68 self._wrapped = Settings(settings_module)
#
# ImproperlyConfigured: Requested setting DATABASES, but settings are not configured. You must either define the environment variable DJANGO_SETTINGS_MODULE or call settings.configure() before accessing settings.
